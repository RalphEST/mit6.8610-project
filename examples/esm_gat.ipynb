# %%
# basics + plotting
import os, sys
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 250
plt.rcParams["font.family"] = "sans serif"

# PyTorch imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler

# custom
PROJECT_PATH = '/'.join(os.getcwd().split('/')[:-1])
sys.path.insert(1, PROJECT_PATH)

from utils import (
    data_utils, 
    eval_utils, 
    plotting_utils, 
    train_test_utils
)

from models import (
    esm_transfer_learning,
    gnn
)

import importlib
data_utils = importlib.reload(data_utils)
eval_utils = importlib.reload(eval_utils)
train_test_utils = importlib.reload(train_test_utils)
esm_transfer_learning = importlib.reload(esm_transfer_learning)
gnn = importlib.reload(gnn)

if torch.cuda.is_available():
    print('using cuda')
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

data = data_utils.load_variation_dataset("../data/data/", 
                                         "../gene_list.txt", 
                                         ["embeddings", "indicators"], 
                                         "../data/phenotypes_hcm_only.parquet",
                                         predict=["hcm"], 
                                         low_memory=True,
                                         embeddings_file='esm1v_embeddings.npy',
                                         ppi_graph_path='../ppi_networks/string_interactions_short.tsv')

train_dataset, test_dataset = data.train_test_split(balance_on=['hcm','ethnicity'])

def train_epoch(model, 
                train_loader, 
                optimizer, 
                loss_fn, 
                log_every=10):
    model.train()
    total_loss = 0
    
    all_labels, all_preds = [],[]
    for i, batch in enumerate(train_loader):
        # move batch dictionary to device
        data_utils.batch_dict_to_device(batch, device)
        labels = batch['labels']
        
        # compute prediction and loss
        preds = model(batch)
        loss = loss_fn(preds, labels)

        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # tracking
        total_loss += loss.item()
        all_labels.append(labels.cpu())
        all_preds.append(preds.flatten().detach().cpu())
        
        # logging
        if (i % log_every == 0):
            print(f"\tBatch {i} | BCE Loss: {loss.item():.4f}")
    
    metrics = eval_utils.get_metrics(torch.cat(all_labels), 
                                     torch.cat(all_preds))
    metrics['loss'] = total_loss
    
    return metrics

def test(model, 
         test_loader, 
         loss_fn):
    model.eval()
    total_loss = 0
    all_labels, all_preds = [],[]
    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            # move batch dictionary to device
            data_utils.batch_dict_to_device(batch, device)
            labels = batch['labels']

            # compute prediction and loss
            preds = model(batch)
            loss = loss_fn(preds, labels)

            # tracking
            total_loss += loss.item()
            
            all_labels.append(labels.cpu())
            all_preds.append(preds.flatten().detach().cpu())
            
            # logging
            if (i % 10 == 0):
                print(f"\tBatch {i} | BCE Loss: {loss.item():.4f}")
    
    metrics = eval_utils.get_metrics(torch.cat(all_labels), 
                                     torch.cat(all_preds))
    metrics['loss'] = total_loss
    
    return metrics

def train(model, 
          train_dataset,
          test_dataset,
          lr=1e-3, 
          n_epochs=16,
          batch_size=32):
    
    train_loader = DataLoader(
        dataset = train_dataset, 
        batch_size = batch_size,
        sampler = WeightedRandomSampler(train_dataset.weights('hcm',
                                                              flatten_factor=1), 
                                        num_samples = len(train_dataset)),
        num_workers=10
    )
    
    test_loader = DataLoader(
        dataset = test_dataset,
        batch_size = batch_size,
        num_workers=10
    )
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    loss_fn = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    track_metrics = {'train':{i:None for i in range(n_epochs)}, 
                     'test': {i:None for i in range(n_epochs)}}
    
    for epoch in range(n_epochs):
        print(f"Epoch #{epoch}:")
        train_metrics = train_epoch(model, 
                                    train_loader, 
                                    optimizer, 
                                    loss_fn,
                                    log_every=10)
        print("Train metrics:")
        eval_utils.print_metrics(train_metrics)
        test_metrics = test(model, 
                            test_loader, 
                            loss_fn)
        print("Test metrics:")
        eval_utils.print_metrics(test_metrics)
        
        track_metrics['train'][epoch] = train_metrics
        track_metrics['test'][epoch] = test_metrics
    
    return track_metrics


gat_params = {
    'in_dim': 0,
    'embed_dim': 256,
    'n_heads': 4,
    'n_nodes': 0,
    'mlp_hidden_dims': [128],
    'mlp_actn': 'gelu'
}

gcn_params = {
    'in_dim': 0,
    'embed_dim': 256,
    'n_nodes': 0,
    'mlp_hidden_dims': [256],
    'mlp_actn': 'leakyrelu'
}

mlp_params = {
    'in_dim': 0,
    'hidden_dims': [],
    'out_dim':0,
    'actn': 'None'
}

model = esm_transfer_learning.ESMTransferLearner(
    esm_model_name="esm1v_t33_650M_UR90S_1",
    agg_emb_method="weighted_average", 
    predict_method="gat",
    n_genes=29,
    predictor_params=gat_params,
    add_residue_features=data.get_feature_dimensions(['indicators']),
    edge_index=data.edge_index.to('cuda')
)

# %%
model = nn.DataParallel(model)

# %%
model_metrics = train(model, 
                      train_dataset,
                      test_dataset, 
                      lr=1e-4, 
                      n_epochs=3,
                      batch_size=32)
# Out:
# Epoch #0:
# 	Batch 0 | BCE Loss: 0.6954
# 	Batch 10 | BCE Loss: 0.7041
# 	Batch 20 | BCE Loss: 0.6880
# 	Batch 30 | BCE Loss: 0.6956
# 	Batch 40 | BCE Loss: 0.7010
# 	Batch 50 | BCE Loss: 0.7042
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f3862bd6d30>
# Traceback (most recent call last):
#   File "/home/rae715/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1510, in __del__
#     self._shutdown_workers()
#   File "/home/rae715/.local/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1474, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/n/app/anaconda/v3/lib/python3.9/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/n/app/anaconda/v3/lib/python3.9/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/n/app/anaconda/v3/lib/python3.9/multiprocessing/connection.py", line 936, in wait
#     ready = selector.select(timeout)
#   File "/n/app/anaconda/v3/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 model_metrics = train(model,
#       2                       train_dataset,
#       3                       test_dataset,
#       4                       lr=1e-4,
#       5                       n_epochs=3,
#       6                       batch_size=32)
#
# Input In [14], in train(model, train_dataset, test_dataset, lr, n_epochs, batch_size)
#     102 for epoch in range(n_epochs):
#     103     print(f"Epoch #{epoch}:")
# --> 104     train_metrics = train_epoch(model,
#     105                                 train_loader,
#     106                                 optimizer,
#     107                                 loss_fn,
#     108                                 log_every=10)
#     109     print("Train metrics:")
#     110     eval_utils.print_metrics(train_metrics)
#
# Input In [14], in train_epoch(model, train_loader, optimizer, loss_fn, log_every)
#       9 all_labels, all_preds = [],[]
#      10 for i, batch in enumerate(train_loader):
#      11     # move batch dictionary to device
# ---> 12     data_utils.batch_dict_to_device(batch, device)
#      13     labels = batch['labels']
#      15     # compute prediction and loss
#
# File /n/groups/marks/databases/ukbiobank/users/ralphest/mit6.8610-project/utils/data_utils.py:350, in batch_dict_to_device(batch_dict, device)
#     348     batch_dict[k] = v.to(device).float()
#     349 elif isinstance(v, dict):
# --> 350     batch_dict_to_device(v, device)
#
# File /n/groups/marks/databases/ukbiobank/users/ralphest/mit6.8610-project/utils/data_utils.py:348, in batch_dict_to_device(batch_dict, device)
#     346 for k,v in batch_dict.items():
#     347     if torch.is_tensor(v):
# --> 348         batch_dict[k] = v.to(device).float()
#     349     elif isinstance(v, dict):
#     350         batch_dict_to_device(v, device)
#
# KeyboardInterrupt:

# %%
def plot_metrics(metrics, axes):
    metric_types = list(metrics['train'][0].keys())
    for mt,ax in zip(metric_types, axes.flatten()):
        ax.plot([x[mt] for x in model_metrics['train'].values()])
        ax.plot([x[mt] for x in model_metrics['test'].values()])
        ax.set_title(mt)
    axes[0,0].legend(['train', 'test'])
    
fig, axes = plt.subplots(2,3,figsize=(12,6), constrained_layout=True)

plot_metrics(model_metrics, axes)
# fig.savefig('../figures/lr_initial.png')
